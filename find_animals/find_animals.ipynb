# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import scipy
import sklearn
import skimage

plt.rcParams['figure.figsize'] = [20, 10]

# %%
img = cv2.imread("table_animals_rock.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### Task Overview
#
# Given the above image, we would like to answer the following questions using computer vision or machine learning techniques. The libraries provided in the first cell are the ones that you may use in your solution. You may use the internet to look up any documentation.

# %% [markdown]
# ### 1. Find the coordinates of all the animals on the table

# %% [markdown]
# ### 2. Find a method to distinguish the rhinos from the other animals
